# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS handm_external_loc
    URL 'abfss://handm@dbprojectsstorage.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL dbprojectsextcred)
    COMMENT 'External Location For the handm retail Data Lakehouse'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS handm_bronze_loc
    URL 'abfss://handmbronze@dbprojectsstorage.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL dbprojectsextcred)
    COMMENT 'External Location For the handm bronze retail Data Lakehouse'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS handm_silver_loc
    URL 'abfss://handmsilver@dbprojectsstorage.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL dbprojectsextcred)
    COMMENT 'External Location For the handm silver retail Data Lakehouse'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS handm_gold_loc
    URL 'abfss://handmgold@dbprojectsstorage.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL dbprojectsextcred)
    COMMENT 'External Location For the handm gold retail Data Lakehouse'

# %%
# %sql
CREATE CATALOG IF NOT EXISTS dev_handm MANAGED LOCATION 'abfss://handm@dbprojectsstorage.dfs.core.windows.net/'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS dev_handm.bronze MANAGED LOCATION 'abfss://handm@dbprojectsstorage.dfs.core.windows.net/bronze/'
